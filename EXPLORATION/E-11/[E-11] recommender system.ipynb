# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import math, random

# %% [markdown]
# ## 필요한 변수 정의

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

IMAGE_SIZE = [180, 180]

ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*'
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

BATCH_SIZE = 64
EPOCHS = 30

# %% [markdown]
# ## 데이터 준비하기

# %% [markdown]
# ### 데이터 불러오기

# %%
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))
test_filenames = tf.io.gfile.glob(TEST_PATH)

# %% [markdown]
# ### train / val 데이터 나누기

# %%
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %% [markdown]
# ### 데이터 전처리

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
COUNT_NORMAL
COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(COUNT_NORMAL, "/", COUNT_PNEUMONIA)
# Out:
# 1072 / 3113

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
def get_label(filename):
    file_path = tf.strings.split(filename, os.path.sep)
    return file_path[-2] == "PNEUMONIA"
        
def decode_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, IMAGE_SIZE)
    return image

def process_file(filename):
    label = get_label(filename)
    image = tf.io.read_file(filename)
    image = decode_image(image)
    return image, label

# %%
train_ds = train_list_ds.map(process_file, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_file, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)

TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_file, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(5,math.ceil(BATCH_SIZE/5),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ## 모델링

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation="relu", padding="same"),
        tf.keras.layers.SeparableConv2D(filters, 3, activation="relu", padding="same"),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    return block

def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

# %%
with tf.device('/GPU:0'):
    model = build_model()
    
    MATRICS = [
        "accuracy",
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=MATRICS
    )

# %%
with tf.device("/GPU:0"):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight
    )
# Out:
# Epoch 1/30
# 65/65 [==============================] - 54s 511ms/step - loss: 0.5347 - accuracy: 0.7434 - precision: 0.9162 - recall: 0.7145 - val_loss: 0.5811 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 2/30
# 65/65 [==============================] - 32s 492ms/step - loss: 0.1953 - accuracy: 0.9250 - precision: 0.9870 - recall: 0.9133 - val_loss: 0.7538 - val_accuracy: 0.7393 - val_precision: 0.7393 - val_recall: 1.0000
# Epoch 3/30
# 65/65 [==============================] - 31s 487ms/step - loss: 0.1433 - accuracy: 0.9527 - precision: 0.9873 - recall: 0.9492 - val_loss: 0.8905 - val_accuracy: 0.7373 - val_precision: 0.7373 - val_recall: 1.0000
# Epoch 4/30
# 65/65 [==============================] - 31s 478ms/step - loss: 0.1255 - accuracy: 0.9554 - precision: 0.9847 - recall: 0.9550 - val_loss: 1.0057 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 5/30
# 65/65 [==============================] - 32s 499ms/step - loss: 0.1070 - accuracy: 0.9599 - precision: 0.9829 - recall: 0.9632 - val_loss: 1.1501 - val_accuracy: 0.7373 - val_precision: 0.7373 - val_recall: 1.0000
# Epoch 6/30
# 65/65 [==============================] - 31s 481ms/step - loss: 0.1102 - accuracy: 0.9614 - precision: 0.9866 - recall: 0.9608 - val_loss: 1.2047 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 7/30
# 65/65 [==============================] - 31s 485ms/step - loss: 0.0838 - accuracy: 0.9744 - precision: 0.9887 - recall: 0.9765 - val_loss: 1.3548 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 8/30
# 65/65 [==============================] - 31s 479ms/step - loss: 0.0360 - accuracy: 0.9843 - precision: 0.9963 - recall: 0.9827 - val_loss: 0.1216 - val_accuracy: 0.9609 - val_precision: 0.9972 - val_recall: 0.9496
# Epoch 21/30
# 65/65 [==============================] - 31s 479ms/step - loss: 0.0410 - accuracy: 0.9841 - precision: 0.9951 - recall: 0.9835 - val_loss: 0.0935 - val_accuracy: 0.9717 - val_precision: 0.9714 - val_recall: 0.9907
# Epoch 22/30
# 65/65 [==============================] - 31s 479ms/step - loss: 0.0494 - accuracy: 0.9791 - precision: 0.9944 - recall: 0.9770 - val_loss: 0.0881 - val_accuracy: 0.9727 - val_precision: 0.9677 - val_recall: 0.9960
# Epoch 23/30
# 65/65 [==============================] - 31s 483ms/step - loss: 0.0461 - accuracy: 0.9841 - precision: 0.9957 - recall: 0.9832 - val_loss: 0.0662 - val_accuracy: 0.9756 - val_precision: 0.9854 - val_recall: 0.9815
# Epoch 24/30
# 65/65 [==============================] - 31s 484ms/step - loss: 0.0258 - accuracy: 0.9904 - precision: 0.9986 - recall: 0.9886 - val_loss: 0.2287 - val_accuracy: 0.9473 - val_precision: 0.9986 - val_recall: 0.9298
# Epoch 25/30
# 65/65 [==============================] - 31s 486ms/step - loss: 0.0319 - accuracy: 0.9867 - precision: 0.9977 - recall: 0.9846 - val_loss: 0.1259 - val_accuracy: 0.9639 - val_precision: 0.9931 - val_recall: 0.9575
# Epoch 26/30
# 65/65 [==============================] - 31s 483ms/step - loss: 0.0349 - accuracy: 0.9879 - precision: 0.9959 - recall: 0.9877 - val_loss: 0.0801 - val_accuracy: 0.9766 - val_precision: 0.9919 - val_recall: 0.9760
# Epoch 27/30
# 65/65 [==============================] - 31s 483ms/step - loss: 0.0385 - accuracy: 0.9883 - precision: 0.9942 - recall: 0.9899 - val_loss: 0.0615 - val_accuracy: 0.9805 - val_precision: 0.9842 - val_recall: 0.9894
# Epoch 28/30
# 65/65 [==============================] - 31s 481ms/step - loss: 0.0276 - accuracy: 0.9897 - precision: 0.9978 - recall: 0.9885 - val_loss: 0.0802 - val_accuracy: 0.9795 - val_precision: 0.9946 - val_recall: 0.9775
# Epoch 29/30
# 65/65 [==============================] - 31s 484ms/step - loss: 0.0236 - accuracy: 0.9915 - precision: 0.9986 - recall: 0.9900 - val_loss: 0.1800 - val_accuracy: 0.9648 - val_precision: 1.0000 - val_recall: 0.9522
# Epoch 30/30
# 65/65 [==============================] - 31s 482ms/step - loss: 0.0264 - accuracy: 0.9905 - precision: 0.9976 - recall: 0.9896 - val_loss: 0.4968 - val_accuracy: 0.8838 - val_precision: 1.0000 - val_recall: 0.8413

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(["precision", "recall", "accuracy", "loss"]):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history["val_"+met])
    ax[i].set_title("Model {}".format(met))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 10/10 [==============================] - 9s 904ms/step - loss: 0.6723 - accuracy: 0.8446 - precision: 0.8547 - recall: 0.9051
# Loss: 0.6722609400749207,
# Accuracy: 0.8445512652397156,
# Precision: 0.8547215461730957,
# Recall: 0.9051281809806824
